# %% [markdown]
# # Nếu chỉ chạy xem kết quả thì chạy (1) và (9)

# %% [markdown]
# # 1. Truy cập gg driver

# %%
## sử dụng gg driver
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --upgrade facenet-pytorch

# %% [markdown]
# #2. Crop vào khuôn mặt mỗi ảnh

# %%
import os
import cv2
from facenet_pytorch import MTCNN
from PIL import Image
from tqdm import tqdm
import torch

# ====== CONFIG ======
INPUT_DIR = "/content/drive/MyDrive/Test/img_dataset"
OUTPUT_DIR = "/content/drive/MyDrive/Test/img_out"
IMAGE_SIZE = 112
CONF_THRESHOLD = 0.90

device = "cuda" if torch.cuda.is_available() else "cpu"

mtcnn = MTCNN(
    image_size=IMAGE_SIZE,
    margin=20,
    min_face_size=40,
    thresholds=[0.6, 0.7, 0.7],
    factor=0.709,
    post_process=True,
    device=device
)

os.makedirs(OUTPUT_DIR, exist_ok=True)

# ====== PROCESS ======
for person in os.listdir(INPUT_DIR):
    person_path = os.path.join(INPUT_DIR, person)
    save_path = os.path.join(OUTPUT_DIR, person)
    os.makedirs(save_path, exist_ok=True)

    for img_name in tqdm(os.listdir(person_path), desc=person):
        img_path = os.path.join(person_path, img_name)

        try:
            img = Image.open(img_path).convert("RGB")
            face, prob = mtcnn(img, return_prob=True)

            if face is not None and prob > CONF_THRESHOLD:
                face_img = face.permute(1, 2, 0).cpu().numpy()
                face_img = (face_img + 1) / 2 * 255     # scale [-1,1] → [0,255]
                face_img = face_img.astype("uint8")
                face_img = cv2.cvtColor(face_img, cv2.COLOR_RGB2BGR)

                cv2.imwrite(os.path.join(save_path, img_name), face_img)
            else:
                print(f"⚠ Không detect được mặt: {img_path}")

        except Exception as e:
            print(f"❌ Lỗi ảnh {img_path}: {e}")
# Out:
# ...
# thayongnoi:  80%|████████  | 16/20 [00:05<00:01,  2.86it/s]
# ⚠ Không detect được mặt: /content/drive/MyDrive/Test/img_dataset/thayongnoi/0384_01_02.jpg
# ...
# SonTungMTP: 100%|██████████| 20/20 [00:06<00:00,  3.04it/s]
# ⚠ Không detect được mặt: /content/drive/MyDrive/Test/img_dataset/SonTungMTP/7.jpg
# ...
# LeonardoDiCaprio:   5%|▌         | 1/20 [00:00<00:06,  2.98it/s]
# ❌ Lỗi ảnh /content/drive/MyDrive/Test/img_dataset/LeonardoDiCaprio/leonardo Dicaprio 10.jfif: OpenCV(4.12.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1051: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'imwrite_'
# LeonardoDiCaprio:  10%|█         | 2/20 [00:00<00:06,  2.96it/s]
# ❌ Lỗi ảnh /content/drive/MyDrive/Test/img_dataset/LeonardoDiCaprio/leonardo Dicaprio 14.jfif: OpenCV(4.12.0) /io/opencv/modules/imgcodecs/src/loadsave.cpp:1051: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'imwrite_'
# ...

# %% [markdown]
# # 3. Chia data thanh train val

# %%
import os
import shutil
import random

DATASET_DIR = "/content/drive/MyDrive/Test/img_out"      # dataset gốc
OUTPUT_DIR = "/content/drive/MyDrive/Test/dataset" # thư mục output

TRAIN_RATIO = 0.8

train_dir = os.path.join(OUTPUT_DIR, "train")
val_dir   = os.path.join(OUTPUT_DIR, "val")

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

for person in os.listdir(DATASET_DIR):
    person_path = os.path.join(DATASET_DIR, person)
    if not os.path.isdir(person_path):
        continue

    images = os.listdir(person_path)
    random.shuffle(images)

    split_idx = int(len(images) * TRAIN_RATIO)
    train_imgs = images[:split_idx]
    val_imgs   = images[split_idx:]

    # tạo thư mục cho từng người
    os.makedirs(os.path.join(train_dir, person), exist_ok=True)
    os.makedirs(os.path.join(val_dir, person), exist_ok=True)

    # copy ảnh train
    for img in train_imgs:
        src = os.path.join(person_path, img)
        dst = os.path.join(train_dir, person, img)
        shutil.copy(src, dst)

    # copy ảnh val
    for img in val_imgs:
        src = os.path.join(person_path, img)
        dst = os.path.join(val_dir, person, img)
        shutil.copy(src, dst)

print("✅ Chia train / val hoàn tất")
# Out:
# ✅ Chia train / val hoàn tất

# %%
import os

root = "/content/drive/MyDrive/Test/dataset/train"

for cls in sorted(os.listdir(root)):
    cls_path = os.path.join(root, cls)
    if os.path.isdir(cls_path):
        print(cls, "→", len(os.listdir(cls_path)))
# Out:
# Brad Pitt_300x300 → 16
# Conor_McGregor → 16
# David_Beckham → 16
# Erling_Haaland → 16
# Huy → 9
# Jeff_Bezo → 24
# Jeffray → 16
# Joji → 16
# Khabib → 16
# LeonardoDiCaprio → 16
# Levi → 16
# Messi → 16
# Mixigaming → 16
# Park_Hang_seo → 16
# Robert_Downey_Junior → 16
# Ronaldo_size_300x300 → 16
# SonTungMTP → 15
# Taylor_Swift → 16
# Tobey_Maguire → 16
# Tom_Cruise → 16
# Tom_Hanks → 16
# Will_Smith → 16
# Zhao_Lusi → 16
# antony → 16
# charles_leclerc → 16
# dai_tuong_Vo_Nguyen_Giap → 16
# faker → 16
# j97 → 16
# thayongnoi → 16

# %% [markdown]
# # 4. Data augmentation

# %%
from torchvision import transforms

train_transform = transforms.Compose([
    transforms.Resize((160, 160)),

    transforms.RandomHorizontalFlip(p=0.5),   # lật ngang
    transforms.RandomRotation(10),             # xoay ±10°
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2,
        hue=0.1
    ),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.05, 0.05),                # dịch chuyển
        scale=(0.95, 1.05)                     # zoom nhẹ
    ),

    transforms.ToTensor(),                     # [0,255] → [0,1]
])

val_transform = transforms.Compose([
    transforms.Resize((160, 160)),
    transforms.ToTensor(),
])

# %% [markdown]
# # 5. Import data train + val

# %%
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

train_dataset = ImageFolder(
    root="/content/drive/MyDrive/Test/dataset/train",
    transform=train_transform
)

val_dataset = ImageFolder(
    root="/content/drive/MyDrive/Test/dataset/val",
    transform=val_transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=16,
    shuffle=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=16,
    shuffle=False
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from tqdm import tqdm
import os

# %%
train_dir = "/content/drive/MyDrive/Test/dataset/train"
val_dir   = "/content/drive/MyDrive/Test/dataset/val"

train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
val_dataset   = datasets.ImageFolder(val_dir, transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False)

num_classes = len(train_dataset.classes)
print("Classes:", train_dataset.classes)
print("Num classes:", num_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3887231954.py in <cell line: 0>()
#       2 val_dir   = "/content/drive/MyDrive/Test/dataset/val"
#       3
# ----> 4 train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
#       5 val_dataset   = datasets.ImageFolder(val_dir, transform=val_transform)
#       6
#
# NameError: name 'train_transform' is not defined

# %% [markdown]
# # 6. Resnet

# %%
model = models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 132MB/s]

# %%
model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, num_classes)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-435286925.py in <cell line: 0>()
#       3     nn.ReLU(),
#       4     nn.Dropout(0.5),
# ----> 5     nn.Linear(256, num_classes)
#       6 )
#
# NameError: name 'num_classes' is not defined

# %%
model = model.to(device)

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=1e-4
)

# %% [markdown]
# # 7. train

# %%
def train_one_epoch(model, loader):
    model.train()
    running_loss = 0
    correct = 0
    total = 0

    for images, labels in tqdm(loader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    acc = 100. * correct / total
    return running_loss / len(loader), acc

# %%
def validate(model, loader):
    model.eval()
    running_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in tqdm(loader):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    acc = 100. * correct / total
    return running_loss / len(loader), acc

# %%
epochs = 20

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}")

    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.2f}%")
# Out:
# Epoch 1/20
# ...
# 100%|██████████| 4/4 [00:04<00:00,  1.18s/it]
# Train Loss: 3.3654 | Train Acc: 5.82%
# Val   Loss: 3.2439 | Val   Acc: 8.55%
#
# Epoch 2/20
# ...
# 100%|██████████| 4/4 [00:05<00:00,  1.38s/it]
# Train Loss: 3.0385 | Train Acc: 21.55%
# Val   Loss: 2.9793 | Val   Acc: 22.22%
#
# Epoch 3/20
# ...
# 100%|██████████| 4/4 [00:05<00:00,  1.50s/it]
# Train Loss: 2.7962 | Train Acc: 31.68%
# Val   Loss: 2.6259 | Val   Acc: 35.90%
#
# Epoch 4/20
# ...
# 100%|██████████| 4/4 [00:04<00:00,  1.16s/it]
# Train Loss: 2.4055 | Train Acc: 47.41%
# Val   Loss: 2.3310 | Val   Acc: 41.03%
#
# Epoch 5/20
# ...
# 100%|██████████| 4/4 [00:04<00:00,  1.16s/it]
# Train Loss: 2.1215 | Train Acc: 54.09%
# Val   Loss: 1.9716 | Val   Acc: 57.26%
#
# Epoch 6/20
# ...
# 100%|██████████| 4/4 [00:04<00:00,  1.18s/it]
# Train Loss: 1.7457 | Train Acc: 67.46%
# Val   Loss: 1.6379 | Val   Acc: 65.81%
#
# Epoch 7/20
# ...
# 100%|██████████| 4/4 [00:05<00:00,  1.40s/it]
# Train Loss: 1.4588 | Train Acc: 71.77%
# ...

# %%
epochs = 5

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}/{epochs}")

    train_loss, train_acc = train_one_epoch(model, train_loader)
    val_loss, val_acc = validate(model, val_loader)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}%")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.2f}%")
# Out:
# Epoch 1/5
# ...
# 100%|██████████| 4/4 [00:05<00:00,  1.31s/it]
# Train Loss: 0.0362 | Train Acc: 100.00%
# Val   Loss: 0.3960 | Val   Acc: 89.74%
#
# Epoch 2/5
#  40%|████      | 6/15 [00:26<00:39,  4.35s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-245610256.py in <cell line: 0>()
#       4     print(f"\nEpoch {epoch+1}/{epochs}")
#       5
# ----> 6     train_loss, train_acc = train_one_epoch(model, train_loader)
#       7     val_loss, val_acc = validate(model, val_loader)
#       8
#
# /tmp/ipython-input-804369368.py in train_one_epoch(model, loader)
#       9
#      10         optimizer.zero_grad()
# ---> 11         outputs = model(images)
#      12
#      13         loss = criterion(outputs, labels)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
# ...

# %%
torch.save(model.state_dict(), "resnet18_face_recognition.pth")
print("Model saved!")
# Out:
# Model saved!

# %%
## lưu model vào gg driver để sử dụng
torch.save(
    model.state_dict(),
    "/content/drive/MyDrive/Test/resnet18_face_recognition.pth"
)

# %% [markdown]
# # 8. Test

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import os

# %%
class_names =['Brad Pitt_300x300', 'Conor_McGregor', 'David_Beckham', 'Erling_Haaland', 'Huy', 'Jeff_Bezo', 'Jeffray', 'Joji', 'Khabib', 'LeonardoDiCaprio', 'Levi', 'Messi', 'Mixigaming', 'Park_Hang_seo', 'Robert_Downey_Junior', 'Ronaldo_size_300x300', 'SonTungMTP', 'Taylor_Swift', 'Tobey_Maguire', 'Tom_Cruise', 'Tom_Hanks', 'Will_Smith', 'Zhao_Lusi', 'antony', 'charles_leclerc', 'dai_tuong_Vo_Nguyen_Giap', 'faker', 'j97', 'thayongnoi']
num_classes = len(class_names)

# %%
model = models.resnet18(pretrained=False)

model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, num_classes)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
test_transform = transforms.Compose([
    transforms.Resize((160, 160)),
    transforms.ToTensor(),
])

# %%
image_path = "/content/drive/MyDrive/Test/tl.jpg"

image = Image.open(image_path).convert("RGB")
input_tensor = test_transform(image).unsqueeze(0).to(device)

with torch.no_grad():
    output = model(input_tensor)
    probs = torch.softmax(output, dim=1)
    confidence, predicted = torch.max(probs, 1)

predicted_name = class_names[predicted.item()]
confidence = confidence.item()

print("Predicted:", predicted_name)
print("Confidence:", round(confidence, 3))
# Out:
# Predicted: Taylor_Swift
# Confidence: 0.996

# %% [markdown]
# # 9. End
# Chỉ cần chạy (1) và chạy (9)

# %%
import torch
import torch.nn as nn
import cv2
from facenet_pytorch import MTCNN
from torchvision import models, transforms
from PIL import Image
import os

# %%
model = models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 95.8MB/s]

# %%
class_names =['Brad Pitt_300x300', 'Conor_McGregor', 'David_Beckham', 'Erling_Haaland', 'Huy', 'Jeff_Bezo', 'Jeffray', 'Joji', 'Khabib', 'LeonardoDiCaprio', 'Levi', 'Messi', 'Mixigaming', 'Park_Hang_seo', 'Robert_Downey_Junior', 'Ronaldo_size_300x300', 'SonTungMTP', 'Taylor_Swift', 'Tobey_Maguire', 'Tom_Cruise', 'Tom_Hanks', 'Will_Smith', 'Zhao_Lusi', 'antony', 'charles_leclerc', 'dai_tuong_Vo_Nguyen_Giap', 'faker', 'j97', 'thayongnoi']
num_classes = len(class_names)

# %%
model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, num_classes)
)

# %%
test_transform = transforms.Compose([
    transforms.Resize((160, 160)),
    transforms.ToTensor(),
])

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = model.to(device)
model.load_state_dict(
    torch.load("/content/drive/MyDrive/Test/resnet18_face_recognition.pth",
               map_location="cpu")
)

model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
model = model.to(device)

# %%
img_input = "/content/drive/MyDrive/Test/ximi.jpg"
img = Image.open(img_input).convert("RGB")
IMAGE_SIZE = 112
CONF_THRESHOLD = 0.90

device = "cuda" if torch.cuda.is_available() else "cpu"

mtcnn = MTCNN(
    image_size=IMAGE_SIZE,
    margin=20,
    min_face_size=40,
    thresholds=[0.6, 0.7, 0.7],
    factor=0.709,
    post_process=True,
    device=device
)
face, prob = mtcnn(img, return_prob=True)
if face is not None and prob > CONF_THRESHOLD:
   face_img = face.permute(1, 2, 0).cpu().numpy()
   face_img = (face_img + 1) / 2 * 255     # scale [-1,1] → [0,255]
   face_img = face_img.astype("uint8")
   face_img = cv2.cvtColor(face_img, cv2.COLOR_RGB2BGR)

   ##cv2.imwrite(os.path.join('/content/drive/MyDrive/Test', 'hehe.jpg'), face_img)
else:
  print(f"Không detect được mặt: {img_path}")


##image = Image.open(image_path).convert("RGB")
image = Image.fromarray(face_img)
input_tensor = test_transform(image).unsqueeze(0).to(device)

with torch.no_grad():
    output = model(input_tensor)
    probs = torch.softmax(output, dim=1)
    confidence, predicted = torch.max(probs, 1)

predicted_name = class_names[predicted.item()]
confidence = confidence.item()

print("Predicted:", predicted_name)
print("Confidence:", round(confidence, 3))
# Out:
# Predicted: Mixigaming
# Confidence: 0.899
